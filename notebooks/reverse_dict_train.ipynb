# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Colab_Projects/reverse_dictionary.zip /content/
# !unzip -q /content/reverse_dictionary.zip -d /content/reverse_dictionary

# %cd /content/reverse_dictionary
# !pip install -r requirements.txt
# Out:
# /content/reverse_dictionary
# ...

# %%
# !python -m src.train
# Out:
# [INFO] Config loaded. Device: cuda
# [INFO] Starting training on cuda...
# config.json: 100% 570/570 [00:00<00:00, 2.63MB/s]
# ...
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 109kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 8.37MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 17.3MB/s]
# ...
#  Download complete.
#  Loading data from data/dictionary_data.json (train[:90%])...
#  Loaded 7375 pairs for train[:90%].
#  Loading data from data/dictionary_data.json (train[90%:])...
#  Loaded 7375 pairs for train[90%:].
# model.safetensors: 100% 440M/440M [00:02<00:00, 182MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1229.50it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# ...

# %%
# !cp -r /content/reverse_dictionary/checkpoints /content/drive/MyDrive/Colab_Projects/
